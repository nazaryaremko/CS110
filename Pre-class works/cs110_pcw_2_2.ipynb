# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name and collaborators below:

# %%
NAME = "Nazar Yaremko"
COLLABORATORS = ""

# %% [markdown]
# ---

# %% [markdown]
# # CS110 Pre-class Work 2.2
#
# ## Question 1 (Exercise 3.1-3 of Cormen, et al. )
# Explain why the statement, "The running time of algorithm A is at least $O(n^2)$," is meaningless.

# %% [markdown]
# Because Big O notation means the worst case scenario, whereas this statement tells us about the best case ("at least").

# %% [markdown]
# ## Question 2 (Exercise 3.1-4 of Cormen, et al. )
#
# Is $2^{n+1}=O(2^n)$? Is $2^{2n}=O(2^n)$?

# %% [markdown]
# Not sure about these, but I tried to form an answer that makes sense for me,
#
# Is 2^(n+1)=O(2^n)?
# So this statement means that O(2^n) is an asymptotically tight upper bound to 2^(n+1). However, 2^(n+1) is actually above 2^(n+1) (just by a little bit). I plotted a graph below to show the difference (in that case I added 1000 instead so the difference could be seen). Therefore, it is correct to say that 2^(n)=O(2^(n+1)) instead.
#
# Is 2^2n=O(2^n)?
# Here, as well, 2^2n is actually above 2^n, The second graph I plotted shows it well. Therefore, the statement is incorrect and the correct way is 2^n = O(2^2n).

# %%
list1 = []
list2 = []
x = range(1,10000)
for n in range(1,10000):
    list1.append(2^n)
    list2.append(2^(n+1000))

import matplotlib.pyplot as plt
plt.plot(x, list1, label = "2^n")
plt.plot(x, list2, label = "2^(n+1000)")
plt.legend(loc="upper left")

# %%
list1 = []
list2 = []
x = range(1,10000)
for n in range(1,10000):
    list1.append(2^(2*n))
    list2.append(2^n)

import matplotlib.pyplot as plt
plt.plot(x, list1, label = "2^(2*n)")
plt.plot(x, list2, label = "2^n")
plt.legend(loc="upper left")

# %% [markdown]
# ## Question 3.
# Write a function in Python that solves the maximum-subarray problem using a brute-force approach. Your Python function must:
# * Take as Input an array/list  of numbers
# * Produce the following Output:
#     * the start and end indices of the subarray containing the maximum sum.
#     * value of the maximum subarray (float)

# %%
def bruteforce_max_subarray(A):
    """Implements brute-force maximum subarray finding.
    
    Inputs:
    - A: a NON-EMPTY list of floats
    
    Outputs: A tuple of
    - the start index of the max subarray
    - the end index of the max subarray
    - the value of the maximum subarray
    """
    # YOUR CODE HERE
    raise NotImplementedError()

# %%
def bruteforce_max_subarray(A):
    maximal_sum = float('-inf')
    # I set this to negative infinity because it is smaller than any 
    #maximum sum that could be in any list, so we could initiate the comparisons correctly
    for k in range(0,len(A)):
        #this will be out lower bound
        sum_of = 0
        #creating a veriable that will collect our sums
        for l in range(k, len(A)):
            #this will be the upper bound
            sum_of += A[l]
            #adding the numbers between k and len(A) to calculate a sum
            if sum_of > maximal_sum:
                #comparing the sum to the previous biggest sum
                maximal_sum = sum_of
                #setting the new sum as the biggest sum if the previous equation is satisfied
                low = k
                high = l
    return(low, high, maximal_sum)


bruteforce_max_subarray([-2, -5, 6, -2, -3, 1, 5, -6])
# Out:
# (2, 6, 7)

# %%
assert(bruteforce_max_subarray([-2,1,-1,2,-5]) == (1, 3, 2))
assert(bruteforce_max_subarray([-2, -5, 6, -2, -3, 1, 5, -6]) == (2, 6, 7))

# %% [markdown]
# ## Question 4.
# Test your Python maximum-subarray function using the following input list (from Figure 4.3 of Cormen et al.):
# `A = [13, -3, -25, 20, -3, -16, -23, 18, 20, -7, 12, -5, -22, 15, -4, 7] `
#
# If your Python implementation is correct, your code must return:
# * 43 - which is the answer to the maximum subarray problem, and
# * <7, 10> -the start and the end indices of the max subarray.

# %%
bruteforce_max_subarray([13, -3, -25, 20, -3, -16, -23, 18, 20, -7, 12, -5, -22, 15, -4, 7])
# Out:
# (7, 10, 43)

# %% [markdown]
# ## Question 5. Asymptotic notation.
# Complete the following table using the asymptotic notation that best describes the problem. For example, if both $O(n^3)$ and $O(n)$ are possible for an algorithm, the answer is $O(n)$ because the function $f(n) = O(n)$ provides a tighter and more accurate fit; if both $O(n)$ and $\Theta(n)$ are possible, the correct answer is $\Theta(n)$ because $\Theta(n)$ provides both information about the upper and lower bound, thus it is more accurate than $O(n)$.
#
# You should copy the following table and paste and edit it in the cell below.
#
# Algorithm | Big Oh ($O$) | Big Theta ($\Theta$)
# --- | --- | ---
# Insertion sort |  |
# Selection sort |  |
# Bubble sort |  |
# Finding maximum subarray |  |

# %% [markdown]
# ## Question 5. Asymptotic notation.
# Complete the following table using the asymptotic notation that best describes the problem. For example, if both $O(n^3)$ and $O(n)$ are possible for an algorithm, the answer is $O(n)$ because the function $f(n) = O(n)$ provides a tighter and more accurate fit; if both $O(n)$ and $\Theta(n)$ are possible, the correct answer is $\Theta(n)$ because $\Theta(n)$ provides both information about the upper and lower bound, thus it is more accurate than $O(n)$.
#
# You should copy the following table and paste and edit it in the cell below.
#
# Algorithm | Big Oh ($O$) | Big Theta ($\Theta$)
# --- | --- | ---
# Insertion sort |n^2  |n^2
# Selection sort |n^2 | n^2
# Bubble sort |n^2  | n^2
# Finding maximum subarray |O(nLogn)   |2*(n/2) + n

# %% [markdown]
# ## [Optional] Question 6.
# How can you change this code to make it find the minimum-subarray?

# %%
def bruteforce_min_subarray(A):
    maximal_sum = float('inf')
    #HERE DIFFERENCE: I set this to the positive infinity because it is bigger than any 
    #maximum sum that could be in any list, so we could initiate the comparisons correctly
    for k in range(0,len(A)):
        #this will be out lower bound
        sum_of = 0
        #creating a veriable that will collect our sums
        for l in range(k, len(A)):
            #this will be the upper bound
            sum_of += A[l]
            #adding the numbers between k and len(A) to calculate a sum
            if sum_of < maximal_sum:
                #HERE DIFFERENCE: we just change the sign and try to find the smallest number
                maximal_sum = sum_of
                #setting the new sum as the biggest sum if the previous equation is satisfied
                low = k
                high = l
    return(low, high, maximal_sum)

#Therefore, the difference is that we change negative infinity to positive infinity 
#and change the sign at line 13. 

bruteforce_min_subarray([-2, -5, 6, -2, -3, 1, 5, -6])
# Out:
# (0, 1, -7)

# %%
assert(bruteforce_min_subarray([1]*10)[0] == bruteforce_min_subarray([1]*10)[1])
assert(bruteforce_min_subarray([1]*10)[2] == 1)
